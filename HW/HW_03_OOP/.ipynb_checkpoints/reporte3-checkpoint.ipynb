# %% [markdown]
# Tarea 03
#
# Física Computacional
#
# Edwin Urbina Quiroz|A76588

# %% [markdown]
# I.9. ¿Por qué es una buena práctica sobrecargar operadores?

# %% [markdown]
# Para que la clase que nosotros creamos tenga un comportamiento similar a los ya definidos de manera nativa por el lenguaje. La sobrecarga hace que operación sea más natural y legible su implementación.

# %% [markdown]
# II. Gráfico de la solución de la ecuación diferencial
#
# $$\frac{dy}{dx} = 2(1 - y) - e^{-4x} $$

# %%
from IPython.display import Image, display

# %%
display(Image(filename="rk4_comparacion.png"))
